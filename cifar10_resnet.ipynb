# %%
#import needed classes
import keras
from keras.datasets import cifar10
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,AveragePooling2D,Dropout,BatchNormalization,Activation
from keras.models import Model,Input
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ModelCheckpoint
from math import ceil
import os
from keras.preprocessing.image import ImageDataGenerator


def Unit(x,filters,pool=False):
    res = x
    if pool:
        x = MaxPooling2D(pool_size=(2, 2))(x)
        res = Conv2D(filters=filters,kernel_size=[1,1],strides=(2,2),padding="same")(res)
    out = BatchNormalization()(x)
    out = Activation("relu")(out)
    out = Conv2D(filters=filters, kernel_size=[3, 3], strides=[1, 1], padding="same")(out)

    out = BatchNormalization()(out)
    out = Activation("relu")(out)
    out = Conv2D(filters=filters, kernel_size=[3, 3], strides=[1, 1], padding="same")(out)

    out = keras.layers.add([res,out])

    return out

#Define the model


def MiniModel(input_shape):
    images = Input(input_shape)
    net = Conv2D(filters=32, kernel_size=[3, 3], strides=[1, 1], padding="same")(images)
    net = Unit(net,32)
    net = Unit(net,32)
    net = Unit(net,32)

    net = Unit(net,64,pool=True)
    net = Unit(net,64)
    net = Unit(net,64)

    net = Unit(net,128,pool=True)
    net = Unit(net,128)
    net = Unit(net,128)

    net = Unit(net, 256,pool=True)
    net = Unit(net, 256)
    net = Unit(net, 256)

    net = BatchNormalization()(net)
    net = Activation("relu")(net)
    net = Dropout(0.25)(net)

    net = AveragePooling2D(pool_size=(4,4))(net)
    net = Flatten()(net)
    net = Dense(units=10,activation="softmax")(net)

    model = Model(inputs=images,outputs=net)

    return model

#load the cifar10 dataset
(train_x, train_y) , (test_x, test_y) = cifar10.load_data()

#normalize the data
train_x = train_x.astype('float32') / 255
test_x = test_x.astype('float32') / 255

#Subtract the mean image from both train and test set
train_x = train_x - train_x.mean()
test_x = test_x - test_x.mean()

#Divide by the standard deviation
train_x = train_x / train_x.std(axis=0)
test_x = test_x / test_x.std(axis=0)


datagen = ImageDataGenerator(rotation_range=10,
                             width_shift_range=5. / 32,
                             height_shift_range=5. / 32,
                             horizontal_flip=True)

# Compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(train_x)



#Encode the labels to vectors
train_y = keras.utils.to_categorical(train_y,10)
test_y = keras.utils.to_categorical(test_y,10)

#define a common unit


input_shape = (32,32,3)
model = MiniModel(input_shape)

#Print a Summary of the model

model.summary()
#Specify the training components
model.compile(optimizer=Adam(0.001),loss="categorical_crossentropy",metrics=["accuracy"])



epochs = 50
steps_per_epoch = ceil(50000/128)

# Fit the model on the batches generated by datagen.flow().
model.fit_generator(datagen.flow(train_x, train_y, batch_size=128),
                    validation_data=[test_x,test_y],
                    epochs=epochs,steps_per_epoch=steps_per_epoch, verbose=1, workers=4)


#Evaluate the accuracy of the test dataset
accuracy = model.evaluate(x=test_x,y=test_y,batch_size=128)
model.save("cifar10model.h5")
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 32)   896         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 32)   9248        activation_26[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 32, 32)   0           conv2d_28[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 32)   128         add_12[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 32)   9248        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 32, 32)   0           add_12[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 32)   128         add_13[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 32)   9248        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 32)   9248        activation_30[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 32, 32)   0           add_13[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 32)   128         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 64)   18496       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 64)   2112        add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 16, 16, 64)   36928       activation_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 16, 16, 64)   0           conv2d_35[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 64)   256         add_15[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 16, 16, 64)   36928       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16, 16, 64)   256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16, 16, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 16, 16, 64)   36928       activation_34[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 16, 16, 64)   0           add_15[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 64)   256         add_16[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 16, 16, 64)   36928       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16, 16, 64)   256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 64)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 16, 16, 64)   36928       activation_36[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 16, 16, 64)   0           add_16[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 64)     0           add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 64)     256         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 64)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 128)    73856       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 128)    512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 128)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 128)    8320        add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 128)    147584      activation_38[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 128)    0           conv2d_42[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 128)    512         add_18[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 8, 8, 128)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 128)    147584      activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 128)    512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 8, 8, 128)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 8, 128)    147584      activation_40[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 8, 8, 128)    0           add_18[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 128)    512         add_19[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8, 8, 128)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 128)    147584      activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 8, 8, 128)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 128)    147584      activation_42[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 8, 8, 128)    0           add_19[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 128)    0           add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 128)    512         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 4, 4, 128)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 4, 4, 256)    295168      activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 4, 4, 256)    1024        conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4, 4, 256)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 4, 4, 256)    33024       add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 4, 4, 256)    590080      activation_44[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 4, 4, 256)    0           conv2d_49[0][0]
#                                                                  conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 4, 4, 256)    1024        add_21[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 4, 4, 256)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 4, 4, 256)    590080      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 4, 4, 256)    1024        conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 4, 4, 256)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 4, 4, 256)    590080      activation_46[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 4, 4, 256)    0           add_21[0][0]
#                                                                  conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 256)    1024        add_22[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 4, 256)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 4, 4, 256)    590080      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 4, 4, 256)    1024        conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 4, 256)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 4, 4, 256)    590080      activation_48[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 4, 4, 256)    0           add_22[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 4, 4, 256)    1024        add_23[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 4, 4, 256)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4, 4, 256)    0           activation_49[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 256)    0           dropout_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2570        flatten_1[0][0]
# ==================================================================================================
# Total params: 4,374,538
# Trainable params: 4,368,714
# Non-trainable params: 5,824
# __________________________________________________________________________________________________
# Epoch 1/50
# 391/391 [==============================] - 16s 40ms/step - loss: 1.3239 - accuracy: 0.5195 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.8751 - accuracy: 0.6898 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.7022 - accuracy: 0.7537 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.6057 - accuracy: 0.7898 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.5477 - accuracy: 0.8098 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.5047 - accuracy: 0.8245 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 391/391 [==============================] - 15s 38ms/step - loss: 0.4644 - accuracy: 0.8383 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.4311 - accuracy: 0.8513 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.4021 - accuracy: 0.8603 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.3793 - accuracy: 0.8686 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.3541 - accuracy: 0.8747 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 391/391 [==============================] - 15s 38ms/step - loss: 0.3364 - accuracy: 0.8826 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 391/391 [==============================] - 15s 38ms/step - loss: 0.3236 - accuracy: 0.8887 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.3043 - accuracy: 0.8942 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.2882 - accuracy: 0.9003 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.2788 - accuracy: 0.9028 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.2725 - accuracy: 0.9042 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.2566 - accuracy: 0.9111 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.2436 - accuracy: 0.9134 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.2345 - accuracy: 0.9165 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 391/391 [==============================] - 15s 38ms/step - loss: 0.2283 - accuracy: 0.9191 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.2171 - accuracy: 0.9234 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.2097 - accuracy: 0.9258 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1990 - accuracy: 0.9295 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1978 - accuracy: 0.9308 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 391/391 [==============================] - 15s 38ms/step - loss: 0.1852 - accuracy: 0.9351 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1783 - accuracy: 0.9364 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1701 - accuracy: 0.9398 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1640 - accuracy: 0.9420 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1638 - accuracy: 0.9417 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1558 - accuracy: 0.9451 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1514 - accuracy: 0.9459 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1496 - accuracy: 0.9471 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 391/391 [==============================] - 16s 40ms/step - loss: 0.1427 - accuracy: 0.9493 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 391/391 [==============================] - 16s 40ms/step - loss: 0.1397 - accuracy: 0.9508 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1330 - accuracy: 0.9522 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1324 - accuracy: 0.9544 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1245 - accuracy: 0.9554 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1261 - accuracy: 0.9554 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 391/391 [==============================] - 15s 40ms/step - loss: 0.1178 - accuracy: 0.9579 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 391/391 [==============================] - 15s 40ms/step - loss: 0.1181 - accuracy: 0.9577 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1101 - accuracy: 0.9606 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1121 - accuracy: 0.9610 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1123 - accuracy: 0.9597 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1035 - accuracy: 0.9627 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1082 - accuracy: 0.9610 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.0995 - accuracy: 0.9647 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 391/391 [==============================] - 15s 40ms/step - loss: 0.0953 - accuracy: 0.9655 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.0997 - accuracy: 0.9647 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.0966 - accuracy: 0.9650 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# 79/79 [==============================] - 1s 8ms/step - loss: 0.4101 - accuracy: 0.8947
